# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
property=pd.read_csv('property_listings.csv')
# mortgage=pd.read_csv('listing_mortgage_info.csv')
# nearby_homes=pd.read_csv('listing_nearby_homes.csv')
# price_history=pd.read_csv('listing_price_history.csv')
# schools=pd.read_csv('listing_schools_info.csv')
# subtype=pd.read_csv('listing_subtype.csv')
# tax_info=pd.read_csv('listing_tax_info.csv')

# %%
property
# Out:
#               zpid      price     homeStatus       homeType  datePosted  \
# 0       32107262.0   750000.0  Recently Sold   Multi Family  2024-03-19
# 1       20503342.0     3995.0  Recently Sold      Apartment  2024-09-24
# 2       20183958.0   820000.0  Recently Sold  Single Family  2024-10-27
# 3       32332472.0   550000.0  Recently Sold  Single Family  2024-07-09
# 4      352427429.0   703478.0  Recently Sold  Single Family  2024-06-19
# ...            ...        ...            ...            ...         ...
# 18773   16735997.0   994000.0       For Sale          Condo  2024-11-24
# 18774   16823913.0  1390000.0       For Sale  Single Family  2024-11-24
# 18775   17176040.0   795000.0       For Sale  Single Family  2024-11-24
# 18776   15177502.0   950000.0       For Sale  Single Family  2024-11-24
# 18777   82362288.0   615000.0       For Sale      Townhouse  2024-11-24
#
#                      streetAddress           city state  zipcode  \
# 0                     7417 87th Rd        Jamaica    NY  11421.0
# 1         1300 Midvale Ave APT 510    Los Angeles    CA  90024.0
# 2                   8300 Capps Ave     Northridge    CA  91324.0
# 3                   433 Hamden Ave  Staten Island    NY  10306.0
# 4                  504 Edwin St #8      Nashville    TN  37207.0
# ...                            ...            ...   ...      ...
# 18773           17616 Corte Potosi      San Diego    CA  92128.0
# 18774            10941 Waterton Rd      San Diego    CA  92131.0
# 18775           3954 Via Del Bardo     San Ysidro    CA  92173.0
# 18776               22 Chicago Way  San Francisco    CA  94112.0
# 18777  1015 NE 123rd Street UNIT B        Seattle    WA  98125.0
#
#                      county  ...  rentZestimate  bathrooms bedrooms  \
# 0             Queens County  ...         2930.0        2.0      NaN
# 1        Los Angeles County  ...         3867.0        2.0      2.0
# 2        Los Angeles County  ...         4540.0        2.0      3.0
# 3           Richmond County  ...         2668.0        1.0      2.0
# 4           Davidson County  ...         3599.0        4.0      4.0
# ...                     ...  ...            ...        ...      ...
# 18773      San Diego County  ...         3056.0        2.0      2.0
# 18774      San Diego County  ...         5248.0        4.0      5.0
# 18775      San Diego County  ...         3744.0        3.0      4.0
# 18776  San Francisco County  ...         3578.0        2.0      2.0
# 18777           King County  ...         2991.0        2.0      3.0
#
#        pageViewCount  favoriteCount  propertyTaxRate  timeOnZillow  \
# 0               20.0            0.0             0.86       9 hours
# 1              187.0            5.0             1.16       9 hours
# 2               21.0            0.0             1.16       9 hours
# 3               96.0            0.0             0.89       9 hours
# 4                7.0            0.0             0.57       9 hours
# ...              ...            ...              ...           ...
# 18773           45.0            1.0             1.17       5 hours
# 18774          440.0           35.0             1.17       7 hours
# 18775           35.0            2.0             1.17      21 hours
# 18776          596.0           33.0             1.18         1 day
# 18777          216.0           19.0             0.77      22 hours
#
#          dateSold                                                url  \
# 0      2024-11-24  https://www.zillow.com/homedetails/7417-87th-R...
# 1      2024-11-24  https://www.zillow.com/homedetails/1300-Midval...
# 2      2024-11-24  https://www.zillow.com/homedetails/8300-Capps-...
# 3      2024-11-24  https://www.zillow.com/homedetails/433-Hamden-...
# 4      2024-11-24  https://www.zillow.com/homedetails/504-Edwin-S...
# ...           ...                                                ...
# 18773         NaN  https://www.zillow.com/homedetails/17616-Corte...
# 18774         NaN  https://www.zillow.com/homedetails/10941-Water...
# 18775         NaN  https://www.zillow.com/homedetails/3954-Via-De...
# 18776         NaN  https://www.zillow.com/homedetails/22-Chicago-...
# 18777         NaN  https://www.zillow.com/homedetails/1015-NE-123...
#
#                           lastUpdated
# 0      2024-11-25 09:04:11.007468 UTC
# 1      2024-11-25 09:04:11.007468 UTC
# 2      2024-11-25 09:04:11.007468 UTC
# 3      2024-11-25 09:04:11.007468 UTC
# 4      2024-11-25 09:04:11.007468 UTC
# ...                               ...
# 18773  2024-11-25 05:33:30.941175 UTC
# 18774  2024-11-25 05:33:30.941175 UTC
# 18775  2024-11-25 05:33:30.941175 UTC
# 18776  2024-11-25 05:33:30.941175 UTC
# 18777  2024-11-25 05:33:30.941175 UTC
#
# [18778 rows x 23 columns]

# %%
from skimpy import skim
skim(property)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 18778  │ │ string      │ 12    │                                                          │
# │ │ Number of columns │ 23     │ │ float64     │ 11    │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column  ┃ NA   ┃ NA %    ┃ mean     ┃ sd      ┃ p0      ┃ p25      ┃ p50     ┃ p75      ┃ p100    ┃ hist   ┃  │
# │ ┡━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━┩  │
# │ │ zpid    │    1 │ 0.00532 │ 26320000 │ 5277000 │ 1070000 │ 26250000 │ 5296000 │ 32190000 │ 2147000 │ █▁   ▁ │  │
# │ │         │      │ 5380764 │        0 │      00 │         │          │       0 │        0 │     000 │        │  │
# │ │         │      │  724678 │          │         │         │          │         │          │         │        │  │
# │ │ price   │    1 │ 0.00532 │   673000 │ 3631000 │       0 │   252500 │  400000 │   690000 │ 4750000 │   █    │  │
# │ │         │      │ 5380764 │          │         │         │          │         │          │      00 │        │  │
# │ │         │      │  724678 │          │         │         │          │         │          │         │        │  │
# │ │ zipcode │    1 │ 0.00532 │    51670 │   28080 │    2108 │    30050 │   44140 │    78250 │   98200 │ ▃█▄▁▅▅ │  │
# │ │         │      │ 5380764 │          │         │         │          │         │          │         │        │  │
# │ │         │      │  724678 │          │         │         │          │         │          │         │        │  │
# │ │ yearBui │  753 │ 4.01001 │     1975 │   88.59 │       0 │     1950 │    1980 │     2008 │    9999 │    █   │  │
# │ │ lt      │      │ 1715837 │          │         │         │          │         │          │         │        │  │
# │ │         │      │     682 │          │         │         │          │         │          │         │        │  │
# │ │ livingA │ 1109 │ 5.90584 │     1878 │    1349 │       0 │     1190 │    1633 │     2266 │   49090 │   █    │  │
# │ │ rea     │      │ 7268079 │          │         │         │          │         │          │         │        │  │
# │ │         │      │     667 │          │         │         │          │         │          │         │        │  │
# │ │ rentZes │ 5087 │ 27.0902 │     2949 │    2943 │     673 │     1801 │    2338 │     3294 │  109000 │   █    │  │
# │ │ timate  │      │ 1195015 │          │         │         │          │         │          │         │        │  │
# │ │         │      │    4437 │          │         │         │          │         │          │         │        │  │
# │ │ bathroo │  474 │ 2.52423 │    4.737 │   284.6 │       0 │        2 │       2 │        3 │   38450 │   █    │  │
# │ │ ms      │      │ 0482479 │          │         │         │          │         │          │         │        │  │
# │ │         │      │    4974 │          │         │         │          │         │          │         │        │  │
# │ │ bedroom │  659 │ 3.50942 │     6.22 │   381.2 │       0 │        3 │       3 │        4 │   51270 │   █    │  │
# │ │ s       │      │ 5923953 │          │         │         │          │         │          │         │        │  │
# │ │         │      │     563 │          │         │         │          │         │          │         │        │  │
# │ │ pageVie │    2 │ 0.01065 │    203.5 │   396.8 │       0 │       50 │     120 │      235 │   18880 │   █    │  │
# │ │ wCount  │      │ 0761529 │          │         │         │          │         │          │         │        │  │
# │ │         │      │  449356 │          │         │         │          │         │          │         │        │  │
# │ │ favorit │    2 │ 0.01065 │    12.47 │   27.48 │       0 │        2 │       6 │       14 │    1518 │   █    │  │
# │ │ eCount  │      │ 0761529 │          │         │         │          │         │          │         │        │  │
# │ │         │      │  449356 │          │         │         │          │         │          │         │        │  │
# │ │ propert │    2 │ 0.01065 │    1.035 │   0.491 │       0 │     0.67 │    0.86 │     1.47 │       2 │  ▅█▃▅▃ │  │
# │ │ yTaxRat │      │ 0761529 │          │         │         │          │         │          │         │        │  │
# │ │ e       │      │  449356 │          │         │         │          │         │          │         │        │  │
# │ └─────────┴──────┴─────────┴──────────┴─────────┴─────────┴──────────┴─────────┴──────────┴─────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃       ┃          ┃          ┃          ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA    ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ homeStat │     1 │ 0.005325 │ Other    │ Pre      │ For Rent │ Recently  │     8.99 │         2 │    37513 │  │
# │ │ us       │       │ 38076472 │          │ Foreclos │          │ Sold      │          │           │          │  │
# │ │          │       │     4678 │          │ ure      │          │           │          │           │          │  │
# │ │ homeType │     1 │ 0.005325 │ Lot      │ Single   │ Apartmen │ Townhouse │     10.8 │       1.7 │    31256 │  │
# │ │          │       │ 38076472 │          │ Family   │ t        │           │          │           │          │  │
# │ │          │       │     4678 │          │          │          │           │          │           │          │  │
# │ │ datePost │    28 │ 0.149110 │ 2024-03- │ 2024-03- │ 2022-02- │ 2024-12-2 │       10 │         1 │    18750 │  │
# │ │ ed       │       │ 66141229 │ 19       │ 19       │ 22       │ 6         │          │           │          │  │
# │ │          │       │      098 │          │          │          │           │          │           │          │  │
# │ │ streetAd │     1 │ 0.005325 │ Linden   │ Montour  │  1051    │ YoRanch   │     19.3 │       3.9 │    73907 │  │
# │ │ dress    │       │ 38076472 │          │ Plan,    │ Swinton  │ Plan,     │          │           │          │  │
# │ │          │       │     4678 │          │ Somerset │ Avenue   │ YoHouse   │          │           │          │  │
# │ │          │       │          │          │ Meadows  │          │ Homes     │          │           │          │  │
# │ │          │       │          │          │ :        │          │           │          │           │          │  │
# │ │          │       │          │          │ Broadvie │          │           │          │           │          │  │
# │ │          │       │          │          │ w and    │          │           │          │           │          │  │
# │ │          │       │          │          │ Stonehil │          │           │          │           │          │  │
# │ │          │       │          │          │ l        │          │           │          │           │          │  │
# │ │          │       │          │          │ Collecti │          │           │          │           │          │  │
# │ │          │       │          │          │ on       │          │           │          │           │          │  │
# │ │ city     │     1 │ 0.005325 │ Buda     │ Springfi │ Acworth  │ Woodstock │     8.81 │       1.3 │    23542 │  │
# │ │          │       │ 38076472 │          │ eld      │          │           │          │           │          │  │
# │ │          │       │     4678 │          │ Gardens  │          │           │          │           │          │  │
# │ │ state    │     1 │ 0.005325 │ NY       │ NY       │ AZ       │ WA        │        2 │         1 │    18777 │  │
# │ │          │       │ 38076472 │          │          │          │           │          │           │          │  │
# │ │          │       │     4678 │          │          │          │           │          │           │          │  │
# │ │ county   │    15 │ 0.079880 │ King     │ San      │ Adams    │ Wilson    │     14.2 │       2.1 │    39445 │  │
# │ │          │       │ 71147087 │ County   │ Francisc │ County   │ County    │          │           │          │  │
# │ │          │       │      017 │          │ o County │          │           │          │           │          │  │
# │ │ livingAr │  1105 │ 5.884545 │ sqft     │ sqft     │ sqft     │ sqft      │        4 │      0.94 │    17673 │  │
# │ │ eaUnits  │       │ 74502076 │          │          │          │           │          │           │          │  │
# │ │          │       │        9 │          │          │          │           │          │           │          │  │
# │ │ timeOnZi │   319 │ 1.698796 │ 1 day    │ 10       │ 1 day    │ 98 days   │     6.71 │         2 │    36918 │  │
# │ │ llow     │       │ 46394717 │          │ minutes  │          │           │          │           │          │  │
# │ │          │       │       22 │          │          │          │           │          │           │          │  │
# │ │ dateSold │ 15092 │ 80.37064 │ 2024-11- │ 2024-11- │ 1971-06- │ 2024-11-2 │       10 │       0.2 │     3686 │  │
# │ │          │       │ 65012248 │ 24       │ 24       │ 01       │ 9         │          │           │          │  │
# │ │          │       │        4 │          │          │          │           │          │           │          │  │
# │ │ url      │     1 │ 0.005325 │ https:// │ https:// │ https:// │ https://w │       86 │         1 │    18777 │  │
# │ │          │       │ 38076472 │ www.zill │ www.zill │ www.zill │ ww.zillow │          │           │          │  │
# │ │          │       │     4678 │ ow.com/c │ ow.com/h │ ow.com/c │ .com/home │          │           │          │  │
# │ │          │       │          │ ommunity │ omedetai │ ommunity │ details/T │          │           │          │  │
# │ │          │       │          │ /j5/2059 │ ls/0-Use │ /101-wes │ imken-Dr- │          │           │          │  │
# │ │          │       │          │ 033468_z │ -Directi │ t-14th/2 │ 89-San-An │          │           │          │  │
# │ │          │       │          │ pid/     │ ons-Belo │ 05915204 │ tonio-TX- │          │           │          │  │
# │ │          │       │          │          │ w-Not-Al │ 3_zpid/  │ 78260/351 │          │           │          │  │
# │ │          │       │          │          │ l-Street │          │ 372587_zp │          │           │          │  │
# │ │          │       │          │          │ s-Contin │          │ id/       │          │           │          │  │
# │ │          │       │          │          │ uous-12- │          │           │          │           │          │  │
# │ │          │       │          │          │ San-Pedr │          │           │          │           │          │  │
# │ │          │       │          │          │ o-CA-907 │          │           │          │           │          │  │
# │ │          │       │          │          │ 31/20529 │          │           │          │           │          │  │
# │ │          │       │          │          │ 97345_zp │          │           │          │           │          │  │
# │ │          │       │          │          │ id/      │          │           │          │           │          │  │
# │ │ lastUpda │     0 │        0 │ 2024-11- │ 2024-11- │ 2024-11- │ 2024-11-2 │     29.9 │         3 │    56334 │  │
# │ │ ted      │       │          │ 26       │ 25       │ 20       │ 9         │          │           │          │  │
# │ │          │       │          │ 06:02:41 │ 09:04:11 │ 23:54:07 │ 09:03:23. │          │           │          │  │
# │ │          │       │          │ .14363   │ .007468  │ .941846  │ 877552    │          │           │          │  │
# │ │          │       │          │ UTC      │ UTC      │ UTC      │ UTC       │          │           │          │  │
# │ └──────────┴───────┴──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
property["lastUpdated"]=pd.to_datetime(property['lastUpdated'],format='mixed')
property["datePosted"]=pd.to_datetime(property['datePosted'],format='mixed')
property
# Out:
#               zpid      price     homeStatus       homeType datePosted  \
# 0       32107262.0   750000.0  Recently Sold   Multi Family 2024-03-19
# 1       20503342.0     3995.0  Recently Sold      Apartment 2024-09-24
# 2       20183958.0   820000.0  Recently Sold  Single Family 2024-10-27
# 3       32332472.0   550000.0  Recently Sold  Single Family 2024-07-09
# 4      352427429.0   703478.0  Recently Sold  Single Family 2024-06-19
# ...            ...        ...            ...            ...        ...
# 18773   16735997.0   994000.0       For Sale          Condo 2024-11-24
# 18774   16823913.0  1390000.0       For Sale  Single Family 2024-11-24
# 18775   17176040.0   795000.0       For Sale  Single Family 2024-11-24
# 18776   15177502.0   950000.0       For Sale  Single Family 2024-11-24
# 18777   82362288.0   615000.0       For Sale      Townhouse 2024-11-24
#
#                      streetAddress           city state  zipcode  \
# 0                     7417 87th Rd        Jamaica    NY  11421.0
# 1         1300 Midvale Ave APT 510    Los Angeles    CA  90024.0
# 2                   8300 Capps Ave     Northridge    CA  91324.0
# 3                   433 Hamden Ave  Staten Island    NY  10306.0
# 4                  504 Edwin St #8      Nashville    TN  37207.0
# ...                            ...            ...   ...      ...
# 18773           17616 Corte Potosi      San Diego    CA  92128.0
# 18774            10941 Waterton Rd      San Diego    CA  92131.0
# 18775           3954 Via Del Bardo     San Ysidro    CA  92173.0
# 18776               22 Chicago Way  San Francisco    CA  94112.0
# 18777  1015 NE 123rd Street UNIT B        Seattle    WA  98125.0
#
#                      county  ...  rentZestimate  bathrooms bedrooms  \
# 0             Queens County  ...         2930.0        2.0      NaN
# 1        Los Angeles County  ...         3867.0        2.0      2.0
# 2        Los Angeles County  ...         4540.0        2.0      3.0
# 3           Richmond County  ...         2668.0        1.0      2.0
# 4           Davidson County  ...         3599.0        4.0      4.0
# ...                     ...  ...            ...        ...      ...
# 18773      San Diego County  ...         3056.0        2.0      2.0
# 18774      San Diego County  ...         5248.0        4.0      5.0
# 18775      San Diego County  ...         3744.0        3.0      4.0
# 18776  San Francisco County  ...         3578.0        2.0      2.0
# 18777           King County  ...         2991.0        2.0      3.0
#
#        pageViewCount  favoriteCount  propertyTaxRate  timeOnZillow  \
# 0               20.0            0.0             0.86       9 hours
# 1              187.0            5.0             1.16       9 hours
# 2               21.0            0.0             1.16       9 hours
# 3               96.0            0.0             0.89       9 hours
# 4                7.0            0.0             0.57       9 hours
# ...              ...            ...              ...           ...
# 18773           45.0            1.0             1.17       5 hours
# 18774          440.0           35.0             1.17       7 hours
# 18775           35.0            2.0             1.17      21 hours
# 18776          596.0           33.0             1.18         1 day
# 18777          216.0           19.0             0.77      22 hours
#
#          dateSold                                                url  \
# 0      2024-11-24  https://www.zillow.com/homedetails/7417-87th-R...
# 1      2024-11-24  https://www.zillow.com/homedetails/1300-Midval...
# 2      2024-11-24  https://www.zillow.com/homedetails/8300-Capps-...
# 3      2024-11-24  https://www.zillow.com/homedetails/433-Hamden-...
# 4      2024-11-24  https://www.zillow.com/homedetails/504-Edwin-S...
# ...           ...                                                ...
# 18773         NaN  https://www.zillow.com/homedetails/17616-Corte...
# 18774         NaN  https://www.zillow.com/homedetails/10941-Water...
# 18775         NaN  https://www.zillow.com/homedetails/3954-Via-De...
# 18776         NaN  https://www.zillow.com/homedetails/22-Chicago-...
# 18777         NaN  https://www.zillow.com/homedetails/1015-NE-123...
#
#                            lastUpdated
# 0     2024-11-25 09:04:11.007468+00:00
# 1     2024-11-25 09:04:11.007468+00:00
# 2     2024-11-25 09:04:11.007468+00:00
# 3     2024-11-25 09:04:11.007468+00:00
# 4     2024-11-25 09:04:11.007468+00:00
# ...                                ...
# 18773 2024-11-25 05:33:30.941175+00:00
# 18774 2024-11-25 05:33:30.941175+00:00
# 18775 2024-11-25 05:33:30.941175+00:00
# 18776 2024-11-25 05:33:30.941175+00:00
# 18777 2024-11-25 05:33:30.941175+00:00
#
# [18778 rows x 23 columns]

# %%
property['homeStatus'].value_counts()
# Out:
# homeStatus
# For Sale           15003
# Recently Sold       3712
# Pending               30
# For Rent              13
# Foreclosed             8
# Pre Foreclosure        8
# Other                  3
# Name: count, dtype: int64

# %%
"""from summarytools import dfSummary
dfSummary(property)"""
# Out:
# 'from summarytools import dfSummary\ndfSummary(property)'

# %%
property.duplicated().value_counts()
# Out:
# False    18778
# Name: count, dtype: int64

# %%
property.drop('url',axis=1,inplace=True)
property.drop('dateSold',axis=1,inplace=True)
property.drop('timeOnZillow',axis=1,inplace=True)
property.drop('county',axis=1,inplace=True)
property.drop('streetAddress',axis=1,inplace=True)
property.drop('zpid',axis=1,inplace=True)
property
# Out:
#            price     homeStatus       homeType datePosted           city  \
# 0       750000.0  Recently Sold   Multi Family 2024-03-19        Jamaica
# 1         3995.0  Recently Sold      Apartment 2024-09-24    Los Angeles
# 2       820000.0  Recently Sold  Single Family 2024-10-27     Northridge
# 3       550000.0  Recently Sold  Single Family 2024-07-09  Staten Island
# 4       703478.0  Recently Sold  Single Family 2024-06-19      Nashville
# ...          ...            ...            ...        ...            ...
# 18773   994000.0       For Sale          Condo 2024-11-24      San Diego
# 18774  1390000.0       For Sale  Single Family 2024-11-24      San Diego
# 18775   795000.0       For Sale  Single Family 2024-11-24     San Ysidro
# 18776   950000.0       For Sale  Single Family 2024-11-24  San Francisco
# 18777   615000.0       For Sale      Townhouse 2024-11-24        Seattle
#
#       state  zipcode  yearBuilt  livingArea livingAreaUnits  rentZestimate  \
# 0        NY  11421.0        NaN         NaN             NaN         2930.0
# 1        CA  90024.0     1968.0      1156.0            sqft         3867.0
# 2        CA  91324.0     1957.0      1678.0            sqft         4540.0
# 3        NY  10306.0     1925.0      1200.0            sqft         2668.0
# 4        TN  37207.0     1949.0      1808.0            sqft         3599.0
# ...     ...      ...        ...         ...             ...            ...
# 18773    CA  92128.0     1981.0      1286.0            sqft         3056.0
# 18774    CA  92131.0     1996.0      2468.0            sqft         5248.0
# 18775    CA  92173.0     1979.0      1646.0            sqft         3744.0
# 18776    CA  94112.0     1950.0      1500.0            sqft         3578.0
# 18777    WA  98125.0     2008.0      1406.0            sqft         2991.0
#
#        bathrooms  bedrooms  pageViewCount  favoriteCount  propertyTaxRate  \
# 0            2.0       NaN           20.0            0.0             0.86
# 1            2.0       2.0          187.0            5.0             1.16
# 2            2.0       3.0           21.0            0.0             1.16
# 3            1.0       2.0           96.0            0.0             0.89
# 4            4.0       4.0            7.0            0.0             0.57
# ...          ...       ...            ...            ...              ...
# 18773        2.0       2.0           45.0            1.0             1.17
# 18774        4.0       5.0          440.0           35.0             1.17
# 18775        3.0       4.0           35.0            2.0             1.17
# 18776        2.0       2.0          596.0           33.0             1.18
# 18777        2.0       3.0          216.0           19.0             0.77
#
#                            lastUpdated
# 0     2024-11-25 09:04:11.007468+00:00
# 1     2024-11-25 09:04:11.007468+00:00
# 2     2024-11-25 09:04:11.007468+00:00
# 3     2024-11-25 09:04:11.007468+00:00
# 4     2024-11-25 09:04:11.007468+00:00
# ...                                ...
# 18773 2024-11-25 05:33:30.941175+00:00
# 18774 2024-11-25 05:33:30.941175+00:00
# 18775 2024-11-25 05:33:30.941175+00:00
# 18776 2024-11-25 05:33:30.941175+00:00
# 18777 2024-11-25 05:33:30.941175+00:00
#
# [18778 rows x 17 columns]

# %%
property.dropna(axis=0, subset=['yearBuilt'], inplace=True)
property.dropna(axis=0, subset=['livingArea'], inplace=True)
property.dropna(axis=0, subset=['yearBuilt'], inplace=True)
property.dropna(axis=0, subset=['livingAreaUnits'], inplace=True)
property.dropna(axis=0, subset=['datePosted'], inplace=True)
property
# Out:
#            price     homeStatus       homeType datePosted           city  \
# 1         3995.0  Recently Sold      Apartment 2024-09-24    Los Angeles
# 2       820000.0  Recently Sold  Single Family 2024-10-27     Northridge
# 3       550000.0  Recently Sold  Single Family 2024-07-09  Staten Island
# 4       703478.0  Recently Sold  Single Family 2024-06-19      Nashville
# 5       690530.0  Recently Sold  Single Family 2024-06-19      Nashville
# ...          ...            ...            ...        ...            ...
# 18773   994000.0       For Sale          Condo 2024-11-24      San Diego
# 18774  1390000.0       For Sale  Single Family 2024-11-24      San Diego
# 18775   795000.0       For Sale  Single Family 2024-11-24     San Ysidro
# 18776   950000.0       For Sale  Single Family 2024-11-24  San Francisco
# 18777   615000.0       For Sale      Townhouse 2024-11-24        Seattle
#
#       state  zipcode  yearBuilt  livingArea livingAreaUnits  rentZestimate  \
# 1        CA  90024.0     1968.0      1156.0            sqft         3867.0
# 2        CA  91324.0     1957.0      1678.0            sqft         4540.0
# 3        NY  10306.0     1925.0      1200.0            sqft         2668.0
# 4        TN  37207.0     1949.0      1808.0            sqft         3599.0
# 5        TN  37207.0     2024.0      1809.0            sqft         3254.0
# ...     ...      ...        ...         ...             ...            ...
# 18773    CA  92128.0     1981.0      1286.0            sqft         3056.0
# 18774    CA  92131.0     1996.0      2468.0            sqft         5248.0
# 18775    CA  92173.0     1979.0      1646.0            sqft         3744.0
# 18776    CA  94112.0     1950.0      1500.0            sqft         3578.0
# 18777    WA  98125.0     2008.0      1406.0            sqft         2991.0
#
#        bathrooms  bedrooms  pageViewCount  favoriteCount  propertyTaxRate  \
# 1            2.0       2.0          187.0            5.0             1.16
# 2            2.0       3.0           21.0            0.0             1.16
# 3            1.0       2.0           96.0            0.0             0.89
# 4            4.0       4.0            7.0            0.0             0.57
# 5            4.0       4.0            6.0            0.0             0.57
# ...          ...       ...            ...            ...              ...
# 18773        2.0       2.0           45.0            1.0             1.17
# 18774        4.0       5.0          440.0           35.0             1.17
# 18775        3.0       4.0           35.0            2.0             1.17
# 18776        2.0       2.0          596.0           33.0             1.18
# 18777        2.0       3.0          216.0           19.0             0.77
#
#                            lastUpdated
# 1     2024-11-25 09:04:11.007468+00:00
# 2     2024-11-25 09:04:11.007468+00:00
# 3     2024-11-25 09:04:11.007468+00:00
# 4     2024-11-25 09:04:11.007468+00:00
# 5     2024-11-25 09:04:11.007468+00:00
# ...                                ...
# 18773 2024-11-25 05:33:30.941175+00:00
# 18774 2024-11-25 05:33:30.941175+00:00
# 18775 2024-11-25 05:33:30.941175+00:00
# 18776 2024-11-25 05:33:30.941175+00:00
# 18777 2024-11-25 05:33:30.941175+00:00
#
# [17446 rows x 17 columns]

# %%
#property['county'].value_counts()
#property['Postedyear'] = property['datePosted'].dt.year
#property['Postedmonth'] = property['datePosted'].dt.month
#property['Postedday'] = property['datePosted'].dt.day
# property['year'] = property['your_date_column'].dt.year
# property['month'] = property['your_date_column'].dt.month
# property['day'] = property['your_date_column'].dt.day

# %%
property['state'].value_counts()
# Out:
# state
# TX    3091
# FL    1753
# GA    1536
# CA    1434
# NY    1249
# NV    1194
# PA    1046
# IL     774
# OH     731
# TN     656
# NC     556
# AZ     555
# MD     505
# IN     477
# KY     417
# CO     365
# MI     344
# WA     272
# VA     191
# MA     163
# SC     137
# Name: count, dtype: int64

# %%
property['city'].value_counts()
# Out:
# city
# Houston           1149
# Las Vegas         1144
# San Antonio       1011
# Philadelphia       805
# Chicago            773
#                   ...
# Pewee Valley         1
# Laveen Village       1
# Charlestown          1
# Staten island        1
# South Fulton         1
# Name: count, Length: 308, dtype: int64

# %%
property.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17446 entries, 1 to 18777
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            17446 non-null  float64
#  1   homeStatus       17446 non-null  object
#  2   homeType         17446 non-null  object
#  3   datePosted       17446 non-null  datetime64[ns]
#  4   city             17446 non-null  object
#  5   state            17446 non-null  object
#  6   zipcode          17446 non-null  float64
#  7   yearBuilt        17446 non-null  float64
#  8   livingArea       17446 non-null  float64
#  9   livingAreaUnits  17446 non-null  object
#  10  rentZestimate    12879 non-null  float64
#  11  bathrooms        17331 non-null  float64
#  12  bedrooms         17339 non-null  float64
#  13  pageViewCount    17445 non-null  float64
#  14  favoriteCount    17445 non-null  float64
#  15  propertyTaxRate  17445 non-null  float64
#  16  lastUpdated      17446 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(10), object(5)
# memory usage: 2.4+ MB

# %%
property['bathrooms'].fillna(property['bathrooms'].median(),inplace=True)
property['bedrooms'].fillna(property['bedrooms'].median(),inplace=True)
property['pageViewCount'].fillna(property['pageViewCount'].median(),inplace=True)
property['favoriteCount'].fillna(property['favoriteCount'].median(),inplace=True)
property['propertyTaxRate'].fillna(property['propertyTaxRate'].mean(),inplace=True)
property['rentZestimate'].fillna(property['rentZestimate'].mean(),inplace=True)
property.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17446 entries, 1 to 18777
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            17446 non-null  float64
#  1   homeStatus       17446 non-null  object
#  2   homeType         17446 non-null  object
#  3   datePosted       17446 non-null  datetime64[ns]
#  4   city             17446 non-null  object
#  5   state            17446 non-null  object
#  6   zipcode          17446 non-null  float64
#  7   yearBuilt        17446 non-null  float64
#  8   livingArea       17446 non-null  float64
#  9   livingAreaUnits  17446 non-null  object
#  10  rentZestimate    17446 non-null  float64
#  11  bathrooms        17446 non-null  float64
#  12  bedrooms         17446 non-null  float64
#  13  pageViewCount    17446 non-null  float64
#  14  favoriteCount    17446 non-null  float64
#  15  propertyTaxRate  17446 non-null  float64
#  16  lastUpdated      17446 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(10), object(5)
# memory usage: 2.4+ MB
# /tmp/ipykernel_12832/3949238065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   property['bathrooms'].fillna(property['bathrooms'].median(),inplace=True)
# /tmp/ipykernel_12832/3949238065.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   property['bedrooms'].fillna(property['bedrooms'].median(),inplace=True)
# /tmp/ipykernel_12832/3949238065.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   property['pageViewCount'].fillna(property['pageViewCount'].median(),inplace=True)
# /tmp/ipykernel_12832/3949238065.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   property['favoriteCount'].fillna(property['favoriteCount'].median(),inplace=True)
# /tmp/ipykernel_12832/3949238065.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   property['propertyTaxRate'].fillna(property['propertyTaxRate'].mean(),inplace=True)
# /tmp/ipykernel_12832/3949238065.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   property['rentZestimate'].fillna(property['rentZestimate'].mean(),inplace=True)

# %%
property.drop('livingAreaUnits',axis=1,inplace=True)
property
# Out:
#            price     homeStatus       homeType datePosted           city  \
# 1         3995.0  Recently Sold      Apartment 2024-09-24    Los Angeles
# 2       820000.0  Recently Sold  Single Family 2024-10-27     Northridge
# 3       550000.0  Recently Sold  Single Family 2024-07-09  Staten Island
# 4       703478.0  Recently Sold  Single Family 2024-06-19      Nashville
# 5       690530.0  Recently Sold  Single Family 2024-06-19      Nashville
# ...          ...            ...            ...        ...            ...
# 18773   994000.0       For Sale          Condo 2024-11-24      San Diego
# 18774  1390000.0       For Sale  Single Family 2024-11-24      San Diego
# 18775   795000.0       For Sale  Single Family 2024-11-24     San Ysidro
# 18776   950000.0       For Sale  Single Family 2024-11-24  San Francisco
# 18777   615000.0       For Sale      Townhouse 2024-11-24        Seattle
#
#       state  zipcode  yearBuilt  livingArea  rentZestimate  bathrooms  \
# 1        CA  90024.0     1968.0      1156.0         3867.0        2.0
# 2        CA  91324.0     1957.0      1678.0         4540.0        2.0
# 3        NY  10306.0     1925.0      1200.0         2668.0        1.0
# 4        TN  37207.0     1949.0      1808.0         3599.0        4.0
# 5        TN  37207.0     2024.0      1809.0         3254.0        4.0
# ...     ...      ...        ...         ...            ...        ...
# 18773    CA  92128.0     1981.0      1286.0         3056.0        2.0
# 18774    CA  92131.0     1996.0      2468.0         5248.0        4.0
# 18775    CA  92173.0     1979.0      1646.0         3744.0        3.0
# 18776    CA  94112.0     1950.0      1500.0         3578.0        2.0
# 18777    WA  98125.0     2008.0      1406.0         2991.0        2.0
#
#        bedrooms  pageViewCount  favoriteCount  propertyTaxRate  \
# 1           2.0          187.0            5.0             1.16
# 2           3.0           21.0            0.0             1.16
# 3           2.0           96.0            0.0             0.89
# 4           4.0            7.0            0.0             0.57
# 5           4.0            6.0            0.0             0.57
# ...         ...            ...            ...              ...
# 18773       2.0           45.0            1.0             1.17
# 18774       5.0          440.0           35.0             1.17
# 18775       4.0           35.0            2.0             1.17
# 18776       2.0          596.0           33.0             1.18
# 18777       3.0          216.0           19.0             0.77
#
#                            lastUpdated
# 1     2024-11-25 09:04:11.007468+00:00
# 2     2024-11-25 09:04:11.007468+00:00
# 3     2024-11-25 09:04:11.007468+00:00
# 4     2024-11-25 09:04:11.007468+00:00
# 5     2024-11-25 09:04:11.007468+00:00
# ...                                ...
# 18773 2024-11-25 05:33:30.941175+00:00
# 18774 2024-11-25 05:33:30.941175+00:00
# 18775 2024-11-25 05:33:30.941175+00:00
# 18776 2024-11-25 05:33:30.941175+00:00
# 18777 2024-11-25 05:33:30.941175+00:00
#
# [17446 rows x 16 columns]

# %%
property=property.rename(columns={'livingArea':'livingArea in sqft'})
property
# Out:
#            price     homeStatus       homeType datePosted           city  \
# 1         3995.0  Recently Sold      Apartment 2024-09-24    Los Angeles
# 2       820000.0  Recently Sold  Single Family 2024-10-27     Northridge
# 3       550000.0  Recently Sold  Single Family 2024-07-09  Staten Island
# 4       703478.0  Recently Sold  Single Family 2024-06-19      Nashville
# 5       690530.0  Recently Sold  Single Family 2024-06-19      Nashville
# ...          ...            ...            ...        ...            ...
# 18773   994000.0       For Sale          Condo 2024-11-24      San Diego
# 18774  1390000.0       For Sale  Single Family 2024-11-24      San Diego
# 18775   795000.0       For Sale  Single Family 2024-11-24     San Ysidro
# 18776   950000.0       For Sale  Single Family 2024-11-24  San Francisco
# 18777   615000.0       For Sale      Townhouse 2024-11-24        Seattle
#
#       state  zipcode  yearBuilt  livingArea in sqft  rentZestimate  bathrooms  \
# 1        CA  90024.0     1968.0              1156.0         3867.0        2.0
# 2        CA  91324.0     1957.0              1678.0         4540.0        2.0
# 3        NY  10306.0     1925.0              1200.0         2668.0        1.0
# 4        TN  37207.0     1949.0              1808.0         3599.0        4.0
# 5        TN  37207.0     2024.0              1809.0         3254.0        4.0
# ...     ...      ...        ...                 ...            ...        ...
# 18773    CA  92128.0     1981.0              1286.0         3056.0        2.0
# 18774    CA  92131.0     1996.0              2468.0         5248.0        4.0
# 18775    CA  92173.0     1979.0              1646.0         3744.0        3.0
# 18776    CA  94112.0     1950.0              1500.0         3578.0        2.0
# 18777    WA  98125.0     2008.0              1406.0         2991.0        2.0
#
#        bedrooms  pageViewCount  favoriteCount  propertyTaxRate  \
# 1           2.0          187.0            5.0             1.16
# 2           3.0           21.0            0.0             1.16
# 3           2.0           96.0            0.0             0.89
# 4           4.0            7.0            0.0             0.57
# 5           4.0            6.0            0.0             0.57
# ...         ...            ...            ...              ...
# 18773       2.0           45.0            1.0             1.17
# 18774       5.0          440.0           35.0             1.17
# 18775       4.0           35.0            2.0             1.17
# 18776       2.0          596.0           33.0             1.18
# 18777       3.0          216.0           19.0             0.77
#
#                            lastUpdated
# 1     2024-11-25 09:04:11.007468+00:00
# 2     2024-11-25 09:04:11.007468+00:00
# 3     2024-11-25 09:04:11.007468+00:00
# 4     2024-11-25 09:04:11.007468+00:00
# 5     2024-11-25 09:04:11.007468+00:00
# ...                                ...
# 18773 2024-11-25 05:33:30.941175+00:00
# 18774 2024-11-25 05:33:30.941175+00:00
# 18775 2024-11-25 05:33:30.941175+00:00
# 18776 2024-11-25 05:33:30.941175+00:00
# 18777 2024-11-25 05:33:30.941175+00:00
#
# [17446 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
la=LabelEncoder()
OR=OrdinalEncoder()
property['homeType']=la.fit_transform(property[['homeType']])
property['homeStatus']=la.fit_transform(property[['homeStatus']])
property['state']=la.fit_transform(property[['state']])
property['city']=la.fit_transform(property[['city']])
#property['county']=la.fit_transform(property[['county']])
property
# Out:
# /home/houssemeddine/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/houssemeddine/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/houssemeddine/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/houssemeddine/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#            price  homeStatus  homeType datePosted  city  state  zipcode  \
# 1         3995.0           5         0 2024-09-24   160      1  90024.0
# 2       820000.0           5         5 2024-10-27   191      1  91324.0
# 3       550000.0           5         5 2024-07-09   266     13  10306.0
# 4       703478.0           5         5 2024-06-19   182     17  37207.0
# 5       690530.0           5         5 2024-06-19   182     17  37207.0
# ...          ...         ...       ...        ...   ...    ...      ...
# 18773   994000.0           1         1 2024-11-24   244      1  92128.0
# 18774  1390000.0           1         5 2024-11-24   244      1  92131.0
# 18775   795000.0           1         5 2024-11-24   248      1  92173.0
# 18776   950000.0           1         5 2024-11-24   246      1  94112.0
# 18777   615000.0           1         6 2024-11-24   252     20  98125.0
#
#        yearBuilt  livingArea in sqft  rentZestimate  bathrooms  bedrooms  \
# 1         1968.0              1156.0         3867.0        2.0       2.0
# 2         1957.0              1678.0         4540.0        2.0       3.0
# 3         1925.0              1200.0         2668.0        1.0       2.0
# 4         1949.0              1808.0         3599.0        4.0       4.0
# 5         2024.0              1809.0         3254.0        4.0       4.0
# ...          ...                 ...            ...        ...       ...
# 18773     1981.0              1286.0         3056.0        2.0       2.0
# 18774     1996.0              2468.0         5248.0        4.0       5.0
# 18775     1979.0              1646.0         3744.0        3.0       4.0
# 18776     1950.0              1500.0         3578.0        2.0       2.0
# 18777     2008.0              1406.0         2991.0        2.0       3.0
#
#        pageViewCount  favoriteCount  propertyTaxRate  \
# 1              187.0            5.0             1.16
# 2               21.0            0.0             1.16
# 3               96.0            0.0             0.89
# 4                7.0            0.0             0.57
# 5                6.0            0.0             0.57
# ...              ...            ...              ...
# 18773           45.0            1.0             1.17
# 18774          440.0           35.0             1.17
# 18775           35.0            2.0             1.17
# 18776          596.0           33.0             1.18
# 18777          216.0           19.0             0.77
#
#                            lastUpdated
# 1     2024-11-25 09:04:11.007468+00:00
# 2     2024-11-25 09:04:11.007468+00:00
# 3     2024-11-25 09:04:11.007468+00:00
# 4     2024-11-25 09:04:11.007468+00:00
# 5     2024-11-25 09:04:11.007468+00:00
# ...                                ...
# 18773 2024-11-25 05:33:30.941175+00:00
# 18774 2024-11-25 05:33:30.941175+00:00
# 18775 2024-11-25 05:33:30.941175+00:00
# 18776 2024-11-25 05:33:30.941175+00:00
# 18777 2024-11-25 05:33:30.941175+00:00
#
# [17446 rows x 16 columns]

# %%
property['datePosted']=pd.to_datetime(property['datePosted'],format='mixed')
dates=property['datePosted']
property.drop('datePosted',axis=1,inplace=True)
property.drop('lastUpdated',axis=1,inplace=True)
property.drop('zipcode',axis=1,inplace=True)
property.drop('rentZestimate',axis=1,inplace=True)
property.drop('pageViewCount',axis=1,inplace=True)
property.drop('favoriteCount',axis=1,inplace=True)
#property.drop('yearBuilt',axis=1,inplace=True)
property
# Out:
#            price  homeStatus  homeType  city  state  yearBuilt  \
# 1         3995.0           5         0   160      1     1968.0
# 2       820000.0           5         5   191      1     1957.0
# 3       550000.0           5         5   266     13     1925.0
# 4       703478.0           5         5   182     17     1949.0
# 5       690530.0           5         5   182     17     2024.0
# ...          ...         ...       ...   ...    ...        ...
# 18773   994000.0           1         1   244      1     1981.0
# 18774  1390000.0           1         5   244      1     1996.0
# 18775   795000.0           1         5   248      1     1979.0
# 18776   950000.0           1         5   246      1     1950.0
# 18777   615000.0           1         6   252     20     2008.0
#
#        livingArea in sqft  bathrooms  bedrooms  propertyTaxRate
# 1                  1156.0        2.0       2.0             1.16
# 2                  1678.0        2.0       3.0             1.16
# 3                  1200.0        1.0       2.0             0.89
# 4                  1808.0        4.0       4.0             0.57
# 5                  1809.0        4.0       4.0             0.57
# ...                   ...        ...       ...              ...
# 18773              1286.0        2.0       2.0             1.17
# 18774              2468.0        4.0       5.0             1.17
# 18775              1646.0        3.0       4.0             1.17
# 18776              1500.0        2.0       2.0             1.18
# 18777              1406.0        2.0       3.0             0.77
#
# [17446 rows x 10 columns]

# %%
property['bedrooms'].value_counts()
property['bedrooms'].astype(int)
property['bedrooms'].astype(int)
property=property[(property['bathrooms']<18) & (property['bedrooms']<18)]
print(property['bathrooms'].value_counts())
# Out:
# bathrooms
# 2.0     6856
# 3.0     5115
# 1.0     2778
# 4.0     1709
# 5.0      498
# 6.0      199
# 7.0       79
# 0.0       70
# 8.0       52
# 9.0       23
# 10.0      11
# 12.0       8
# 11.0       6
# 15.0       3
# 14.0       3
# 16.0       2
# 17.0       2
# 13.0       1
# Name: count, dtype: int64

# %%
property=property[property['price']>0]
property['price'].value_counts()
# Out:
# price
# 250000.0     138
# 350000.0     131
# 325000.0     120
# 225000.0     111
# 425000.0     107
#             ...
# 160750.0       1
# 142500.0       1
# 5300000.0      1
# 1523750.0      1
# 499800.0       1
# Name: count, Length: 3709, dtype: int64

# %%
y=property['price']
property.drop('price',axis=1,inplace=True)
y
# Out:
# 1           3995.0
# 2         820000.0
# 3         550000.0
# 4         703478.0
# 5         690530.0
#            ...
# 18773     994000.0
# 18774    1390000.0
# 18775     795000.0
# 18776     950000.0
# 18777     615000.0
# Name: price, Length: 17279, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
X_train,X_valid,y_train,y_valid=train_test_split(property,y,train_size=0.8,test_size=0.2,random_state=42)
model1=Ridge()
model2=XGBRegressor()
model3=RandomForestRegressor(n_estimators=500,random_state=42)

# %%
model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500, random_state=42)

# %%
pred1=model1.predict(X_valid)
print(pred1)
print(mean_absolute_error(y_valid,pred1))
print(r2_score(y_valid,pred1))
# Out:
# [1177582.80064486 2014349.30370932  346800.27765032 ...  291330.19153404
#   316217.27496871   27340.4418982 ]
# 422309.6012401157
# 0.2834359968617788

# %%
pred2=model2.predict(X_valid)
print(pred2)
print(mean_absolute_error(y_valid,pred2))
print(r2_score(y_valid,pred2))
# Out:
# [1062601.1   2471295.     454893.34  ...   20563.643  264544.4
#   134487.06 ]
# 229603.93442182188
# 0.43250360578268476

# %%
pred3=model3.predict(X_valid)
print(pred3)
print(mean_absolute_error(y_valid,pred3))
print(r2_score(y_valid,pred3))
# Out:
# [ 975261.084 2610042.464  405682.682 ...  227554.338  403683.404
#   151423.246]
# 208552.34056018383
# 0.5836294599389851

# %%
import pickle as pk 
import joblib
with open("regression_model.pkl", "wb") as file: # file is a variable for storing the newly created file, it can be anything.
    pk.dump(model2, file)
with open("regression_model.joblib", "wb") as file: # file is a variable for storing the newly created file, it can be anything.
    joblib.dump(model2, file)
